# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sentimentdataset.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0   USA
#
#    Year  Month  Day  Hour
# 0  2023      1   15    12
# 1  2023      1   15     8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
df = df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
df[['Date', 'Time']] = df['Timestamp'].str.split(' ', expand=True)
df = df.drop('Timestamp', axis=1)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.time

# %%
df['Retweets'] = df['Retweets'].astype(int)
df['Likes'] = df['Likes'].astype(int)

# %%
df.isnull().sum()
# Out:
# Text         0
# Sentiment    0
# User         0
# Platform     0
# Hashtags     0
# Retweets     0
# Likes        0
# Country      0
# Year         0
# Month        0
# Day          0
# Hour         0
# Date         0
# Time         0
# dtype: int64

# %%
# setting float format into only 2 decimals points
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.describe()
# Out:
#        Retweets  Likes    Year  Month    Day   Hour  \
# count    732.00 732.00  732.00 732.00 732.00 732.00
# mean      21.51  42.90 2020.47   6.12  15.50  15.52
# min        5.00  10.00 2010.00   1.00   1.00   0.00
# 25%       17.75  34.75 2019.00   3.00   9.00  13.00
# 50%       22.00  43.00 2021.00   6.00  15.00  16.00
# 75%       25.00  50.00 2023.00   9.00  22.00  19.00
# max       40.00  80.00 2023.00  12.00  31.00  23.00
# std        7.06  14.09    2.80   3.41   8.47   4.11
#
#                                 Date
# count                            732
# mean   2020-12-08 05:42:17.704918016
# min              2010-05-15 00:00:00
# 25%              2019-03-08 00:00:00
# 50%              2021-09-20 00:00:00
# 75%              2023-02-26 00:00:00
# max              2023-10-22 00:00:00
# std                              NaN

# %%
df['Hashtags'] = df['Hashtags'].str.replace('#', '')

# %%
df[['Hashtags0', 'Hashtags1', 'Hashtags2']] = df['Hashtags'].str.split(' ', expand=True, n=2)
# Adding a third column 'Hashtags3' to capture all hashtags beyond the first two.
# Using n=2 to limit the split to two splits and avoid None values in the first two columns.

# %%
df = df.drop(['Hashtags', 'Hashtags0'], axis=1)

# %%
df['Hashtags2'] = df['Hashtags2'].str.strip(' ')
df['Hashtags1'] = df['Hashtags1'].str.strip(' ')
df['Sentiment'] = df['Sentiment'].str.strip(' ')
df['Country'] = df['Country'].str.strip(' ')
df['Platform'] = df['Platform'].str.strip(' ')
df['User'] = df['User'].str.strip(' ')

# %%
df.duplicated().sum()
# Out:
# 21

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop = True)
# Out:
#                                                   Text Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...  Positive
# 1     Traffic was terrible this morning.           ...  Negative
# 2     Just finished an amazing workout! 💪          ...  Positive
# 3     Excited about the upcoming weekend getaway!  ...  Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...       ...
# 706  Collaborating on a science project that receiv...     Happy
# 707  Attending a surprise birthday party organized ...     Happy
# 708  Successfully fundraising for a school charity ...     Happy
# 709  Participating in a multicultural festival, cel...     Happy
# 710  Organizing a virtual talent show during challe...     Happy
#
#                                     User   Platform  Retweets  Likes  \
# 0                                User123    Twitter        15     30
# ...

# %%
# download cleaned dataset in csv format
df.to_excel('Social Media Sentiments Analysis.xlsx')
